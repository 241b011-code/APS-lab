# %% [markdown]
# <a href="https://colab.research.google.com/github/241b011-code/APS-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# /# Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2,'E':10},
'B': {'A': 4, 'C': 5, 'D': 10,'E':2},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3},
'E': {'B':10, 'C':100}
}
for s in graph:
  result = dijkstra(graph, s)
  for node in result:
    print("Distance from A to", node, "=", result[node])
  print("\n\n")
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Distance from A to E = 6
#
#
#
# Distance from A to A = 4
# Distance from A to B = 0
# Distance from A to C = 5
# Distance from A to D = 8
# Distance from A to E = 2
#
#
#
# Distance from A to A = 2
# Distance from A to B = 5
# Distance from A to C = 0
# Distance from A to D = 3
# Distance from A to E = 7
#
#
#
# Distance from A to A = 5
# Distance from A to B = 8
# Distance from A to C = 3
# Distance from A to D = 0
# Distance from A to E = 10
#
#
#
# Distance from A to A = 14
# Distance from A to B = 10
# Distance from A to C = 15
# Distance from A to D = 18
# Distance from A to E = 0

# %%
import heapq

def dijkstra(graph, start):

    pq = [(0, start, [start])]
    distances = {node: float('inf') for node in graph}
    paths = {node: [] for node in graph}
    distances[start] = 0
    paths[start] = [start]

    while pq:
        current_distance, current_node, path = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                paths[neighbor] = path + [neighbor]
                heapq.heappush(pq, (distance, neighbor, path + [neighbor]))

    return distances, paths


def create_graph():
    graph = {}
    n = int(input("Enter number of nodes: "))
    for i in range(n):
        node = input(f"Enter name of node {i+1}: ")
        edges = input(f"Enter neighbors of {node} with weights (format: B:4,C:2): ")
        edge_dict = {}
        for e in edges.split(","):
            if ":" in e:
                neighbor, weight = e.split(":")
                edge_dict[neighbor.strip()] = int(weight.strip())
        graph[node] = edge_dict
    return graph


graph=create_graph()
# graph = {
#     'A': {'B': 4, 'C': 2, 'E': 10},
#     'B': {'A': 4, 'C': 5, 'D': 10, 'E': 2},
#     'C': {'A': 2, 'B': 5, 'D': 3},
#     'D': {'B': 10, 'C': 3, 'F': 7},
#     'E': {'B': 10, 'C': 100, 'G': 8},
#     'F': {'D': 7, 'G': 1},
#     'G': {'E': 8, 'F': 1}
# }
for source in graph:
    print(f"\nShortest paths from {source}:")
    distances, paths = dijkstra(graph, source)
    for node in graph:
        print(f"Path to {node}: {paths[node]} with total distance {distances[node]}")
# Out:
# Enter number of nodes: 5
# Enter name of node 1: A
# Enter neighbors of A with weights (format: B:4,C:2): B:4,c:2
# Enter name of node 2: B
# Enter neighbors of B with weights (format: B:4,C:2): c:1
# Enter name of node 3: c
# Enter neighbors of c with weights (format: B:4,C:2): d:4,e:5
# Enter name of node 4: d
# Enter neighbors of d with weights (format: B:4,C:2):
# Enter name of node 5: e
# Enter neighbors of e with weights (format: B:4,C:2):
#
# Shortest paths from A:
# Path to A: ['A'] with total distance 0
# Path to B: ['A', 'B'] with total distance 4
# Path to c: ['A', 'c'] with total distance 2
# Path to d: ['A', 'c', 'd'] with total distance 6
# Path to e: ['A', 'c', 'e'] with total distance 7
#
# Shortest paths from B:
# Path to A: [] with total distance inf
# Path to B: ['B'] with total distance 0
# Path to c: ['B', 'c'] with total distance 1
# Path to d: ['B', 'c', 'd'] with total distance 5
# Path to e: ['B', 'c', 'e'] with total distance 6
#
# Shortest paths from c:
# Path to A: [] with total distance inf
# Path to B: [] with total distance inf
# Path to c: ['c'] with total distance 0
# Path to d: ['c', 'd'] with total distance 4
# Path to e: ['c', 'e'] with total distance 5
#
# Shortest paths from d:
# Path to A: [] with total distance inf
# Path to B: [] with total distance inf
# Path to c: [] with total distance inf
# Path to d: ['d'] with total distance 0
# Path to e: [] with total distance inf
#
# Shortest paths from e:
# Path to A: [] with total distance inf
# Path to B: [] with total distance inf
# Path to c: [] with total distance inf
# Path to d: [] with total distance inf
# Path to e: ['e'] with total distance 0

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
