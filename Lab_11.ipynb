# %% [markdown]
# <a href="https://colab.research.google.com/github/241b011-code/APS-lab/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
def tsp(graph, start):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    parent = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][start]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')
        best_next = -1

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost
                    best_next = next_city

        dp[city][mask] = ans
        parent[city][mask] = best_next
        return ans

    # Run DP starting from user-chosen city
    min_cost = visit(start, 1 << start)

    # Reconstruct path
    path = [start]
    mask = 1 << start
    city = start
    while True:
        next_city = parent[city][mask]
        if next_city == -1:
            break
        path.append(next_city)
        mask |= (1<<next_city)
        city = next_city
    path.append(start)  # return to start

    return min_cost, path

# %%
# start = int(input(f"Enter starting city (0 to {n-1}): "))
for i in range(len(graph)):
  min_cost, path = tsp(graph, i)
  print("via: ",i)
  print("Minimum cost:", min_cost)
  print("Path:", path)
  print("\n")
# Out:
# via:  0
# Minimum cost: 13
# Path: [0, 1, 2, 3, 4, 0]
#
#
# via:  1
# Minimum cost: 13
# Path: [1, 2, 3, 4, 0, 1]
#
#
# via:  2
# Minimum cost: 13
# Path: [2, 3, 4, 0, 1, 2]
#
#
# via:  3
# Minimum cost: 13
# Path: [3, 4, 0, 1, 2, 3]
#
#
# via:  4
# Minimum cost: 13
# Path: [4, 0, 1, 2, 3, 4]
